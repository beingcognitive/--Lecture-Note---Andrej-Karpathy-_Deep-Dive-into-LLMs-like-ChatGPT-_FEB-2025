# %% [markdown]
# # 17. DeepSeek-R1

# %% [markdown]
# 다시 전체 프로세스를 살펴보면, (1) Pretraining과 (2) SFT과정은 상당히 표준화되었지만, 아직 (3) RL과정은 굉장히 초창기임.
#
# OpenAI와 같은 회사들이 RL에 대해서 많은 연구를 진행하지만, 이에 대해서 공개적으로 내용을 밝힌 적은 없었음.
#
# 그렇기 때문에, 지난 1월에 발표된 DeepSeek-R1 에 공개된 RL 기법이 큰 의미를 갖는 것.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 18. AlphaGo

# %% [markdown]
# # 19. Reinforcement Learning from Human Feedback (RLHF)

# %% [markdown]
# # 20. Preview of Things to Come

# %% [markdown]
# # 21. Keeping track of LLMs

# %% [markdown]
# # 22. Where to find LLMs

# %% [markdown]
# # 23. Grand Summary
