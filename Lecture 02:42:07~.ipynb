# %% [markdown]
# # 18. AlphaGo

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 사실은 RL의 emergent 역량을 이미 2017년 AlphaGo 사례에서 확인한 바 있음.
#
# ![image-2.png](attachment:image-2.png)
#
# 이 차트에서 볼 수 있는 것처럼,
#
# human expert를 imitate하는 SFT로는 사람(이세돌사범)을 뛰어넘지 못함.
#
# 그러나, RL은 기존에 없었던 수많은 수를 실험적으로 탐색하면서 사람(이세돌사범)을 뛰어넘는 스코어를 만들어냄

# %% [markdown]
# 동일한 접근 방식이 LLM에 도입되는 과정에 있으며,
#
# AlphaGo의 Move 37과 같은 순간을 LLM에서도 곧 확인하게 되지 않을까 생각함.
#
# (예를 들면, 사람이 생각하지 못한 비유라던가, 새로운 사고 기법이라던가, 기존 언어의 틀을 벗어나서 thinking에 최적화된 <b>모델들만의 언어</b>를 만들어낼지도 모르는 일!!! )
#
# (* 리눅스 창시자인 리누스 토발즈도 비슷한 얘기를 한 적이 있습니다. AI가 사람이 알아듣지 못하는 언어로 코딩하게 될 가능성.)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 19. Reinforcement Learning from Human Feedback (RLHF)

# %% [markdown]
# 위에서 다룬 논리적 사고의 문제는 <b>verifiable domain</b>애 속하기 때문에,
#
# llm judge를 활용하여 정답 ($3)을 맞췄는지, 그 논리적 흐름은 맞는지
#
# 사람의 개입 없이 RL을 진행할 수 있음.

# %% [markdown]
# 그러나, joke와 같은 <b>un-verifiable domain</b>에서의 RL은 무엇을 기준으로 scoring을 해야할까?
#
# <== 여기에 RLHF (Reinforcement Learning from Human Feedback)이 필요하게 됨
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 20. Preview of Things to Come

# %% [markdown]
# # 21. Keeping track of LLMs

# %% [markdown]
# # 22. Where to find LLMs

# %% [markdown]
# # 23. Grand Summary
